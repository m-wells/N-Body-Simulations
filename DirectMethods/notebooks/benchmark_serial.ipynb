# %%
#for reading in ascii files
include("../rw_functions.jl");
#contains the leapfrog serial rountine
include("leapfrog_second_order_serial.jl")
# Out:
# integrate_leapfrog_ser (generic function with 1 method)

# %%
setup=read_setup_from_file("test2particle");
mass=get_mass(setup);
initialState=get_initialState(setup);

# %%
nsteps=1000000;
stepsize=0.5;
grav_constant=100.;

tic();
pos=integrate_leapfrog_ser(initialState,mass,nsteps,stepsize,grav_constant);
toc();
# Out:
# elapsed time: 3
# .535395017 seconds

# %%
using PyPlot;
numparticles = size(initialState)[1]; #the number of rows of state
linesize=mass./(maximum(mass))
for i=1:numparticles
    x=transpose(pos[i,:,1]);
    y=transpose(pos[i,:,2]);
    #z=transpose(pos[i,:,3]);
   #print(x)
    plot(x,y,linewidth=10*linesize[i])
end
xlim(-100000,100000)
ylim(-100000,100000)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0577584f28>)
# (-100000,100000)

# %%
write_pos_out(pos,"test")
# Out:
# Successfully printed:
# ../pos_solutions/test_x.csv
# Successfully printed:
# ../pos_solutions/test_y.csv
# Successfully printed:
# ../pos_solutions/test_z.csv
