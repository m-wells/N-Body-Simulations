# %%
#put it here so it doesn't try and load on every process
using PyPlot
# Out:
# INFO: Loading help data...

# %%
#for reading in ascii files
include("../rw_functions.jl");
#sets the desired number of processes
include("../set_procs.jl")
set_procs(5)
# Out:
# Using 5
#  processes
# Using 4 workers

# %%
#contains the leapfrog parallel rountine
require("leapfrog_second_order_parallel.jl")

# %% [markdown]
# ###read in a ascii file

# %%
setup=read_setup_from_file("test3particles");
mass=get_mass(setup);
initialState=get_initialState(setup);
# Out:
# read_setup_from_file not defined
# while loading In[1], in expression starting on line 1

# %%
nsteps=100000;
stepsize=0.5;
grav_constant=0.1;

tic();
pos=integrate_leapfrog(initialState,mass,nsteps,stepsize,grav_constant);
toc();
# Out:
# elapsed time: 387
# .377424179 seconds

# %%
numparticles = size(initialState)[1]; #the number of rows of state
for i=1:numparticles
    x=transpose(pos[i,:,1]);
    y=transpose(pos[i,:,2]);
    #z=transpose(pos[i,:,3]);
   #print(x)
    plot(x,y,linewidth=5.0)
end
#xlim(-2000,2000)
#ylim(-500,500)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f38aefb2c18>)
